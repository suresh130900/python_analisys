# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the File

# %%
reliance = pd.read_csv("RELIANCE.NS.csv")

reliance
# Out:
#            Date         Open         High          Low        Close  \
# 0    2022-04-04  2655.449951  2675.000000  2641.649902  2663.699951
# 1    2022-04-05  2651.100098  2669.899902  2620.699951  2626.050049
# 2    2022-04-06  2587.100098  2634.500000  2587.100098  2619.050049
# 3    2022-04-07  2595.100098  2606.000000  2567.000000  2572.850098
# 4    2022-04-08  2560.000000  2625.000000  2560.000000  2615.649902
# ..          ...          ...          ...          ...          ...
# 244  2023-03-27  2217.500000  2254.000000  2200.199951  2237.550049
# 245  2023-03-28  2245.000000  2256.500000  2237.000000  2248.000000
# 246  2023-03-29  2239.000000  2244.800049  2211.100098  2234.699951
# 247  2023-03-31  2255.000000  2343.449951  2254.699951  2331.050049
# 248  2023-04-03  2345.000000  2349.000000  2315.000000  2328.800049
#
#        Adj Close    Volume
# 0    2655.704346   3659307
# 1    2618.167480   6068663
# 2    2611.188477   5656703
# 3    2565.127197   7151632
# ...

# %% [markdown]
# Correcting the Date Format

# %%
reliance["Date"] = pd.to_datetime(reliance.Date)
reliance = reliance.set_index("Date")
reliance["Close"].plot(legend= True, figsize=(15,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ITC Data

# %%
itc = pd.read_csv("ITC.NS.csv")
itc

itc["Date"] = pd.to_datetime(itc.Date)

itc = itc.set_index("Date")
itc

itc["Close"].plot(legend= True,figsize=(15,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# TATA ELXSI DATA

# %%
tata = pd.read_csv("TATAELXSI.NS.csv")
tata

tata["Date"] = pd.to_datetime(tata.Date)

tata = tata.set_index("Date")
tata

tata["Close"].plot(legend= True, figsize=(15,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Moving Average to the Reliance Data

# %%
#declaring the days of the moving average
Days = 50

#Adding a new Coloum

col_name = "Moving Average for " + str(Days) + " Days"

reliance[col_name] = reliance["Close"].rolling(Days).mean()
reliance

reliance[["Close","Moving Average for 50 Days"]].plot(legend= True, figsize=(15,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Moving Average for ITC

# %%
Days = 50

col_name_itc = "Moving Average for "+ str(Days) + " Days"

itc[col_name] = itc["Close"].rolling(Days).mean()
itc

itc[["Close","Moving Average for 50 Days"]].plot(legend= True, figsize=(15,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Moving Average for TATA

# %%
Days = 50

col_name = "Moving Average for " + str(Days) + " Days"

tata[col_name] = tata["Close"].rolling(Days).mean()
tata

tata[["Close","Moving Average for 50 Days"]].plot(legend= True, figsize=(15,10))

tata
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-04-04  8988.000000  9164.400391  8931.500000  9009.700195  8964.042969
# 2022-04-05  9090.000000  9090.000000  8850.000000  8878.349609  8833.358398
# 2022-04-06  8875.000000  8990.000000  8762.000000  8893.650391  8848.582031
# 2022-04-07  8907.000000  8938.250000  8703.000000  8747.799805  8703.469727
# 2022-04-08  8791.549805  9088.000000  8621.000000  8685.200195  8641.187500
# ...                 ...          ...          ...          ...          ...
# 2023-03-27  6005.000000  6029.799805  5942.000000  5956.399902  5956.399902
# 2023-03-28  5986.200195  5986.200195  5882.549805  5926.149902  5926.149902
# 2023-03-29  5929.000000  5976.000000  5900.049805  5956.049805  5956.049805
# 2023-03-31  5985.850098  6039.950195  5946.000000  5959.100098  5959.100098
# 2023-04-03  6070.000000  6097.000000  5975.250000  6011.299805  6011.299805
#
#             Volume  Moving Average for 50 Days
# ...

# %% [markdown]
# Multiple Moving Average for Reliance

# %%
Days = [10,100,200]

for day in Days:
    col_name = "Moving Average for " + str(day) + " Days"
    reliance[col_name] = reliance["Close"].rolling(day).mean()
reliance

reliance[["Close","Moving Average for 10 Days","Moving Average for 100 Days","Moving Average for 200 Days","Moving Average for 50 Days"]].plot(subplots=False,figsize=(15,10))
# Out:
# <Axes: xlabel='Date'>
